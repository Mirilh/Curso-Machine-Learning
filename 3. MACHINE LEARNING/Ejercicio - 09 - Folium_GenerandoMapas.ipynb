# %% [markdown]
# # Generando mapas con Python

# %% [markdown]
# ## Introducción
#
#
# En este laboratorio aprenderemos a crear distintos mapas interactivos. Para ello utilizaremos una nueva librería llamada Folium, una librería creada con el objetivo de visualizar datos geoespaciales. También destacamos que estas visualizaciones es posible realizarlas con plotly, pero hay un límite de veces que podemos llamar a la API para datos geoespaciales, a no ser que paguemos. Por otro lado, folium es completamente gratuito y mas potente.

# %% [markdown]
# 2.  Inmigración a Canadá de 1980 a 2013 - [Flujos migratorios internacionales hacia y desde países seleccionados - La revisión de 2015](http://www.un.org/en/development/desa/population/migration/data/empirical2/migrationflows.shtml?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDV0101ENSkillsNetwork20297740-2021-01-01) del sitio web de las Naciones Unidas. El conjunto de datos contiene datos anuales sobre los flujos de migrantes internacionales registrados por los países de destino. Los datos presentan tanto las entradas como las salidas según el lugar de nacimiento, ciudadanía o lugar de residencia anterior/posterior tanto para extranjeros como para nacionales. Para esta lección, nos centraremos en los datos de inmigración canadiense

# %% [markdown]
# # Importando las librerías

# %%
import numpy as np 
import pandas as pd
import folium

# %% [markdown]
# # Introducción a Folium <a id="4"></a>

# %% [markdown]
# Folium es una potente libería de Python que permite crear diferentes tipos de mapas utilizando la librería de javascrip [Leaflet](https://leafletjs.com). Los mapas de Folium son interactivos lo que les da un valor añadido ya que pueden ser integrados en dashboards.

# %% [markdown]
# Generar un mapamundi es bastante sencillo, simplemente creamos un objeto `folium.Map()` y lo mostramos:

# %%
# definimos el mapamundi
world_map = folium.Map()

# mostramos el mapamundi
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_19fbfa6c55e660cb33f89cfd2aec1716 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_19fbfa6c55e660cb33f89cfd2aec1716&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_19fbfa6c55e660cb33f89cfd2aec1716 = L.map(
#                 &quot;map_19fbfa6c55e660cb33f89cfd2aec1716&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6b1902e41ca4e837b80e252601d71339 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_19fbfa6c55e660cb33f89cfd2aec1716);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **Ejercicio:**  Interacciona con el mapa anterior para encontrar Madrid.

# %% [markdown]
# Vamos a crear un mapa centrado alrededor de Canadá y jugar con el nivel de zoom para ver cómo afecta el mapa renderizado.
#
# Es posible personalizar esta definición básica especificando donde debe ser centrado el mapa añadiendo un parámetro `location=[LATITUD,LONGITUD]`. También es posible modificar el zoom mediante el parámetro `zoom_start=int`, cuanto mayor este número mas zoom se realiza.

# %% [markdown]
# #### Ejercicio

# %% [markdown]
# Sabiendo que las coordinadas de Canadá son [56.130, -106.35] realiza un mapa centrado en Canadá. Elige un valor para el parámetro `zoom_start` que permita visualizar correctamente el país entero.

# %%
# location = [56.130, -106.35]
# zoom_start = 8

world_map = folium.Map(location = [56.130, -106.35], zoom_start = 5)
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9d3bc6eb8a42c45ff794eb5ce4280a5d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9d3bc6eb8a42c45ff794eb5ce4280a5d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_9d3bc6eb8a42c45ff794eb5ce4280a5d = L.map(
#                 &quot;map_9d3bc6eb8a42c45ff794eb5ce4280a5d&quot;,
#                 {
#                     center: [56.13, -106.35],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_05c8656c326746adb49221cd032f6755 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9d3bc6eb8a42c45ff794eb5ce4280a5d);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Utiliza la página [geodatos](https://www.geodatos.net/coordenadas) para averiguar las coordenadas de España y así realizar un mapa centrado en España.

# %%
#ESPAÑA
world_map = folium.Map(location = [40.4165, -3.70256], zoom_start = 6)
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_95b305b9e751713f17e671f627823643 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_95b305b9e751713f17e671f627823643&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_95b305b9e751713f17e671f627823643 = L.map(
#                 &quot;map_95b305b9e751713f17e671f627823643&quot;,
#                 {
#                     center: [40.4165, -3.70256],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fcfdcdb9cc90ddfa528a8a912d5575b4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_95b305b9e751713f17e671f627823643);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Otra propiedad interesante de Folium es la posibilidad de generar mapas con diferentes estilos. Por ejemplo:

# %% [markdown]
# ### Stamen Toner Maps
#
# Estos son mapas en blanco y negro con gran contrastre. Perfectos para estudiar cauces de ríos o zonas costeras. Tienen un gran nivel de detalle de los contornos. Por ejemplo:

# %%
world_map = folium.Map(location=[56.130, -106.35], zoom_start=4, tiles='Stamen Toner')
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4a6d6470897bab9c074977eb53c038b9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4a6d6470897bab9c074977eb53c038b9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_4a6d6470897bab9c074977eb53c038b9 = L.map(
#                 &quot;map_4a6d6470897bab9c074977eb53c038b9&quot;,
#                 {
#                     center: [56.13, -106.35],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7ce49eeafcb89d42bf4ad74adc7db56d = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4a6d6470897bab9c074977eb53c038b9);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Stamen Terrain Maps
#
# Estos mapas contienen relieve del terreno y vegetación natural. También mantienen gran parte de la infrastuctura como carreteras pero reduce la nomenclatura a aquellas mas relevantes. Por ejemplo:

# %%
world_map = folium.Map(location=[56.130, -106.35], zoom_start=4, tiles='Stamen Terrain')
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_57980854671a62ab0b6df19265d75e6a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_57980854671a62ab0b6df19265d75e6a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_57980854671a62ab0b6df19265d75e6a = L.map(
#                 &quot;map_57980854671a62ab0b6df19265d75e6a&quot;,
#                 {
#                     center: [56.13, -106.35],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0f9ba79d4e30b39daa5833638b61d549 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_57980854671a62ab0b6df19265d75e6a);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Ejercicio

# %% [markdown]
# Crea dos mapas centrados en España siguiendo los diferentes estilos estudiados en los ejemplos anteriores.

# %%
spain_map_blanco = folium.Map(location = [40.4165, -3.70256], zoom_start = 6, tiles='Stamen Toner')
spain_map_blanco
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e3d49bed58691ed78f74f60b57e80939 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e3d49bed58691ed78f74f60b57e80939&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e3d49bed58691ed78f74f60b57e80939 = L.map(
#                 &quot;map_e3d49bed58691ed78f74f60b57e80939&quot;,
#                 {
#                     center: [40.4165, -3.70256],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_42a3566262cf4052c24793a51eabb9af = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e3d49bed58691ed78f74f60b57e80939);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
spain_map_tierra = folium.Map(location = [40.4165, -3.70256], zoom_start = 6, tiles='Stamen Terrain')
spain_map_tierra

# %% [markdown]
# # Mapas con indicadores

# %% [markdown]
# En esta sección trabajaremos con el siguiente copnjiunto de datos:
# Incidentes del Departamento de Policía de San Francisco del año 2016 - [Police Department Incidents](https://data.sfgov.org/Public-Safety/Police-Department-Incidents-Previous-Year-2016-/ritf-b9ki?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDV0101ENSkillsNetwork20297740-2021-01-01) del portal de datos públicos de San Francisco. Incidentes derivados del sistema de informes de incidentes delictivos del Departamento de Policía de San Francisco (SFPD). Se actualiza diariamente y muestra los datos de todo el año 2016. La dirección y la ubicación se anonimizaron moviéndose a mitad de cuadra o a una intersección.
#
# Descarguemos e importemos los datos sobre los incidentes del departamento de policía usando el método de *pandas* `read_csv()`.
#
# En esta sección trabajaremos con los datos del departamento de policia de San Francisco, un conjunto de datos con los incidentes de 2016. [Police Department Incidents](https://data.sfgov.org/Public-Safety/Police-Department-Incidents-Previous-Year-2016-/ritf-b9ki?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDV0101ENSkillsNetwork20297740-2021-01-01).
#
# Guarda el dataset en un dataframe de pandas

# %% [markdown]
# Descarga el dataset y guárdalo en un dataframe de *pandas*:

# %%
URL = 'https://drive.google.com/u/0/uc?id=1EjYA3BYk0H_Klj-5_PZ79JX--uKfAbsh&export=download'
df_incidents =  pd.read_csv(URL,sep=",")
df_incidents
# Out:
#         Unnamed: 0  IncidntNum        Category  \
# 0                0   120058272     WEAPON LAWS
# 1                1   120058272     WEAPON LAWS
# 2                2   141059263        WARRANTS
# 3                3   160013662    NON-CRIMINAL
# 4                4   160002740    NON-CRIMINAL
# ...            ...         ...             ...
# 150495      150495   161061000         ASSAULT
# 150496      150496   176000742    NON-CRIMINAL
# 150497      150497   176000758   LARCENY/THEFT
# 150498      150498   176000764   LARCENY/THEFT
# 150499      150499   179002868  OTHER OFFENSES
#
#                                                  Descript DayOfWeek  \
# 0                               POSS OF PROHIBITED WEAPON    Friday
# 1          FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE    Friday
# 2                                          WARRANT ARREST    Monday
# 3                                           LOST PROPERTY   Tuesday
# 4                                           LOST PROPERTY    Friday
# ...                                                   ...       ...
# 150495                                            BATTERY    Friday
# 150496                                      LOST PROPERTY    Friday
# 150497                            PETTY THEFT OF PROPERTY  Thursday
# 150498                            GRAND THEFT OF PROPERTY    Friday
# 150499  FRAUDULENT GAME OR TRICK, OBTAINING MONEY OR P...    Friday
#
#                           Date   Time  PdDistrict      Resolution  \
# 0       01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 1       01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 2       04/25/2016 12:00:00 AM  14:59     BAYVIEW  ARREST, BOOKED
# 3       01/05/2016 12:00:00 AM  23:50  TENDERLOIN            NONE
# 4       01/01/2016 12:00:00 AM  00:30     MISSION            NONE
# ...                        ...    ...         ...             ...
# 150495  12/30/2016 12:00:00 AM  21:01        PARK            NONE
# 150496  12/30/2016 12:00:00 AM  08:00     CENTRAL            NONE
# 150497  12/29/2016 12:00:00 AM  20:00     CENTRAL            NONE
# 150498  12/30/2016 12:00:00 AM  10:00     CENTRAL            NONE
# 150499  12/02/2016 12:00:00 AM  14:00    SOUTHERN            NONE
#
#                          Address           X          Y  \
# 0         800 Block of BRYANT ST -122.403405  37.775421
# 1         800 Block of BRYANT ST -122.403405  37.775421
# 2          KEITH ST / SHAFTER AV -122.388856  37.729981
# 3         JONES ST / OFARRELL ST -122.412971  37.785788
# 4           16TH ST / MISSION ST -122.419672  37.765050
# ...                          ...         ...        ...
# 150495       OAK ST / STANYAN ST -122.453982  37.771428
# 150496   JACKSON ST / SANSOME ST -122.401857  37.796626
# 150497       PINE ST / TAYLOR ST -122.412269  37.790673
# 150498  200 Block of STOCKTON ST -122.406659  37.788275
# 150499    800 Block of BRYANT ST -122.403405  37.775421
#
#                                      Location            PdId
# 0        (37.775420706711, -122.403404791479)  12005827212120
# 1        (37.775420706711, -122.403404791479)  12005827212168
# 2       (37.7299809672996, -122.388856204292)  14105926363010
# 3       (37.7857883766888, -122.412970537591)  16001366271000
# 4       (37.7650501214668, -122.419671780296)  16000274071000
# ...                                       ...             ...
# 150495  (37.7714278595913, -122.453981622365)  16106100004134
# 150496  (37.7966261239618, -122.401857374739)  17600074271000
# 150497   (37.7906727649886, -122.41226909106)  17600075806372
# 150498  (37.7882745285785, -122.406658711008)  17600076406374
# 150499   (37.775420706711, -122.403404791479)  17900286809024
#
# [150500 rows x 14 columns]

# %% [markdown]
# Echemos un vistazo al dataset:

# %%
df_incidents.head()
# Out:
#    Unnamed: 0  IncidntNum      Category  \
# 0           0   120058272   WEAPON LAWS
# 1           1   120058272   WEAPON LAWS
# 2           2   141059263      WARRANTS
# 3           3   160013662  NON-CRIMINAL
# 4           4   160002740  NON-CRIMINAL
#
#                                          Descript DayOfWeek  \
# 0                       POSS OF PROHIBITED WEAPON    Friday
# 1  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE    Friday
# 2                                  WARRANT ARREST    Monday
# 3                                   LOST PROPERTY   Tuesday
# 4                                   LOST PROPERTY    Friday
#
#                      Date   Time  PdDistrict      Resolution  \
# 0  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 1  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 2  04/25/2016 12:00:00 AM  14:59     BAYVIEW  ARREST, BOOKED
# 3  01/05/2016 12:00:00 AM  23:50  TENDERLOIN            NONE
# 4  01/01/2016 12:00:00 AM  00:30     MISSION            NONE
#
#                   Address           X          Y  \
# 0  800 Block of BRYANT ST -122.403405  37.775421
# 1  800 Block of BRYANT ST -122.403405  37.775421
# 2   KEITH ST / SHAFTER AV -122.388856  37.729981
# 3  JONES ST / OFARRELL ST -122.412971  37.785788
# 4    16TH ST / MISSION ST -122.419672  37.765050
#
#                                 Location            PdId
# 0   (37.775420706711, -122.403404791479)  12005827212120
# 1   (37.775420706711, -122.403404791479)  12005827212168
# 2  (37.7299809672996, -122.388856204292)  14105926363010
# 3  (37.7857883766888, -122.412970537591)  16001366271000
# 4  (37.7650501214668, -122.419671780296)  16000274071000

# %%
df_incidents['Date'] = pd.to_datetime(df_incidents['Date'])  
df_incidents[df_incidents["Date"] <= "01/01/2016"]
# Out:
#         Unnamed: 0  IncidntNum        Category  \
# 4                4   160002740    NON-CRIMINAL
# 5                5   160002869         ASSAULT
# 9                9   160003641  MISSING PERSON
# 92              92   160014381    NON-CRIMINAL
# 132            132   160000211  OTHER OFFENSES
# ...            ...         ...             ...
# 149835      149835   179001365    NON-CRIMINAL
# 150040      150040   160001758    NON-CRIMINAL
# 150041      150041   160001764    NON-CRIMINAL
# 150042      150042   160001786    NON-CRIMINAL
# 150339      150339   160001861    NON-CRIMINAL
#
#                                   Descript DayOfWeek       Date   Time  \
# 4                            LOST PROPERTY    Friday 2016-01-01  00:30
# 5                                  BATTERY    Friday 2016-01-01  21:35
# 9                             FOUND PERSON    Friday 2016-01-01  10:06
# 92             DEATH REPORT, CAUSE UNKNOWN    Friday 2016-01-01  08:00
# 132     INTERFERRING WITH A POLICE OFFICER    Friday 2016-01-01  00:50
# ...                                    ...       ...        ...    ...
# 149835                     COURTESY REPORT    Friday 2016-01-01  00:01
# 150040        AIDED CASE, MENTAL DISTURBED    Friday 2016-01-01  12:50
# 150041                         FIRE REPORT    Friday 2016-01-01  14:20
# 150042         DEATH REPORT, CAUSE UNKNOWN    Friday 2016-01-01  13:00
# 150339                         FIRE REPORT    Friday 2016-01-01  14:30
#
#         PdDistrict      Resolution                      Address           X  \
# 4          MISSION            NONE         16TH ST / MISSION ST -122.419672
# 5         NORTHERN            NONE        1700 Block of BUSH ST -122.426077
# 9          BAYVIEW            NONE      100 Block of CAMERON WY -122.387182
# 92      TENDERLOIN            NONE        300 Block of ELLIS ST -122.411988
# 132       SOUTHERN  ARREST, BOOKED         MARKET ST / BEALE ST -122.397388
# ...            ...             ...                          ...         ...
# 149835   INGLESIDE            NONE         800 Block of PERU AV -122.423139
# 150040    NORTHERN            NONE         LAGUNA ST / HAYES ST -122.426265
# 150041        PARK            NONE  1400 Block of MCALLISTER ST -122.435901
# 150042     MISSION            NONE     1000 Block of DOLORES ST -122.425379
# 150339   INGLESIDE            NONE         1400 Block of NOE ST -122.431437
#
#                 Y                               Location            PdId
# 4       37.765050  (37.7650501214668, -122.419671780296)  16000274071000
# 5       37.788019   (37.788018555829, -122.426077177375)  16000286904134
# 9       37.720967  (37.7209669615499, -122.387181635995)  16000364175000
# 92      37.785023  (37.7850226622786, -122.411987643595)  16001438161030
# 132     37.792405  (37.7924047319625, -122.397387796127)  16000021127080
# ...           ...                                    ...             ...
# 149835  37.724513  (37.7245125207397, -122.423138704136)  17900136568030
# 150040  37.776463  (37.7764631429143, -122.426265334521)  16000175864020
# 150041  37.778162  (37.7781618593837, -122.435901090932)  16000176468000
# 150042  37.752613  (37.7526134751532, -122.425378994759)  16000178661030
# 150339  37.746224   (37.746224292878, -122.431437413776)  16000186168000
#
# [558 rows x 14 columns]

# %% [markdown]
# El dataset tiene 13 columnas:
# > 1.  **IncidntNum**: Numero identificativo del incidente
# > 2.  **Category**: Categoría del incidente
# > 3.  **Descript**: Descripción del incidente
# > 4.  **DayOfWeek**: Día de la semana que se produjo el incidente
# > 5.  **Date**: Fecha que se produjo el incidente
# > 6.  **Time**: Hora que se produjo el incidente
# > 7.  **PdDistrict**: Departamento de policia que asistió.
# > 8.  **Resolution**: Resolución del incidente.
# > 9.  **Address**: Dirección.
# > 10. **X**: La longitud del punto donde se produjo el incidente.
# > 11. **Y**: La latituddel punto donde se produjo el incidente.
# > 12. **Location**: Una tulpa con la longitud y la latitud.
# > 13. **PdId**: ID del departamento de policia.

# %% [markdown]
# Como intuiremos el dataset no es precisamente pequeño. Veamos el tamaño:

# %%
df_incidents.shape
# Out:
# (150500, 14)

# %% [markdown]
# Así pues, el conjunto de datos consiste en 150,500 incidentes que sucedieron en 2016. Realizar la  visuliazación de todos los datos será realmente costoso desde el punto de vista computacional. Por tanto, vamos a limitarnos a los primeros 100.

# %%
# obtenemos los primeros 100 incidentes en el dataframe df_incidents
limit = 100
df_incidents = df_incidents.iloc[0:limit, :]

# %% [markdown]
# Vamos a confirmar que nuestro dataframe ahora consta solo de 100 incidentes.

# %%
df_incidents.shape
# Out:
# (100, 14)

# %% [markdown]
# Ahora que redujimos un poco los datos, visualicemos dónde ocurrieron estos crímenes en la ciudad de San Francisco. Usaremos el estilo predeterminado e inicializaremos el nivel de zoom a 12.

# %%
# Valores de latitud y longitud de San Francisco
latitude = 37.77
longitude = -122.42

# %%
# creamos el mapa y lo mostramos
sanfran_map = folium.Map(location=[latitude, longitude], zoom_start=12)

# mostramos el mapa de San Francisco
sanfran_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6e447b56e9cb681a86783f5421ffac6f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6e447b56e9cb681a86783f5421ffac6f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6e447b56e9cb681a86783f5421ffac6f = L.map(
#                 &quot;map_6e447b56e9cb681a86783f5421ffac6f&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_79b7719dbadddc7438c181ba680c57b6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6e447b56e9cb681a86783f5421ffac6f);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Ahora superpongamos las ubicaciones de los crímenes en el mapa. La forma de hacerlo en **Folium** es crear un *feature group* (grupo de caractarísticas) con sus propias características y estilo y luego agregarlo a `sanfran_map`.

# %%
# instanciamos un feature group para los incidentes en el dataframe
incidents = folium.map.FeatureGroup()

# recorremos los 100 delitos y agregamos cada uno al feature group de incidentes
for lat, lng, in zip(df_incidents.Y, df_incidents.X):
    incidents.add_child(
        folium.features.CircleMarker(
            [lat, lng],
            radius=5, # definimos cuan grande queremos que sean los marcadores circulares
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# añadimos los incidentes al mapa
sanfran_map.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6e447b56e9cb681a86783f5421ffac6f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6e447b56e9cb681a86783f5421ffac6f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6e447b56e9cb681a86783f5421ffac6f = L.map(
#                 &quot;map_6e447b56e9cb681a86783f5421ffac6f&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_79b7719dbadddc7438c181ba680c57b6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6e447b56e9cb681a86783f5421ffac6f);
#
#
#             var feature_group_ea6efce823eedb71aaa6121e812b8c4d = L.featureGroup(
#                 {}
#             ).addTo(map_6e447b56e9cb681a86783f5421ffac6f);
#
#
#             var circle_marker_1b946aa342e56d5bb3089e8b17d36f5d = L.circleMarker(
#                 [37.775420706711, -122.403404791479],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_ea6efce823eedb71aaa6121e812b8c4d);
#
#
#             var circle_marker_449d796e0299b2e038cb02c96b35c627 = L.circleMarker(
#                 [37.775420706711, -122.403404791479],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_ea6efce823eedb71aaa6121e812b8c4d);
#
#
#             var circle_marker_ba24d9d6697109e48eadbfe3cf0eeeee = L.circleMarker(
#                 [37.7299809672996, -122.388856204292],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_ea6efce823eedb71aaa6121e812b8c4d);
#
#
#             var circle_marker_449ac1d2dbf03df219887cfb327ce595 = L.circleMarker(
#                 [37.7857883766888, -122.412970537591],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_ea6efce823eedb71aaa6121e812b8c4d);
#
#
#             var circle_marker_ec2d542505f0e1019f4d1c898b624755 = L.circleMarker(
#                 [37.7650501214668, -122.419671780296],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_ea6efce823eedb71aaa6121e812b8c4d);
#
#
#             var circle_marker_d61876a76c9e26e543396931cca95528 = L.circleMarker(
#                 [37.788018555829, -122.426077177375],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}

# %% [markdown]
# También podemos agregar un texto emergente que se mostrará cuando pase el cursor sobre un marcador. Hagamos que cada marcador muestre la categoría del incidente cuando pase el cursor sobre él.

# %%
# instanciamos un feature group para los incidentes en el dataframe
incidents = folium.map.FeatureGroup()

# recorremos los 100 delitos y agregamos cada uno al feature group de incidentes

# ZIP devuelve los dos valores 
for lat, lng, in zip(df_incidents.Y, df_incidents.X):
    incidents.add_child(
        folium.features.CircleMarker(
            [lat, lng],
            radius=5, # definimos cuan grande queremos que sean los marcadores circulares
            color='yellow',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )

# añadimos el texto emergente a cada marcador en el mapa
latitudes = list(df_incidents.Y)
longitudes = list(df_incidents.X)
labels = list(df_incidents.Category)

for lat, lng, label in zip(latitudes, longitudes, labels):
    folium.Marker([lat, lng], popup=label).add_to(sanfran_map)    
    
# añadimos los incidentes al mapa
sanfran_map.add_child(incidents)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c652820aab349fd00b584a6e2f57af8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c652820aab349fd00b584a6e2f57af8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1c652820aab349fd00b584a6e2f57af8 = L.map(
#                 &quot;map_1c652820aab349fd00b584a6e2f57af8&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a6255831d8bec1d43f15cf130bcbde1f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1c652820aab349fd00b584a6e2f57af8);
#
#
#             var circle_marker_51a3ee3cae3e39adee8aaecd8f648935 = L.circleMarker(
#                 [37.775420706711, -122.403404791479],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1c652820aab349fd00b584a6e2f57af8);
#
#
#         var popup_824d2119e4dfde5dbd2e1aa4cdb6bfe1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ee797b12b3a823eaef506cc480322cff = $(`&lt;div id=&quot;html_ee797b12b3a823eaef506cc480322cff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#             popup_824d2119e4dfde5dbd2e1aa4cdb6bfe1.setContent(html_ee797b12b3a823eaef506cc480322cff);
#
#
#         circle_marker_51a3ee3cae3e39adee8aaecd8f648935.bindPopup(popup_824d2119e4dfde5dbd2e1aa4cdb6bfe1)
#         ;
#
#
#
#
#             var circle_marker_5271a17cec995ad4de8d279cd6d49af6 = L.circleMarker(
#                 [37.775420706711, -122.403404791479],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1c652820aab349fd00b584a6e2f57af8);
#
#
#         var popup_185103e2e6a1a954a0d648bbde1a3a72 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1a17ecf5f2d32e2b58bbfc3e31d9a0d0 = $(`&lt;div id=&quot;html_1a17ecf5f2d32e2b58bbfc3e31d9a0d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#             popup_185103e2e6a1a954a0d648bbde1a3a72.setContent(html_1a17ecf5f2d32e2b58bbfc3e31d9a0d0);
#
#
#         circle_marker_5271a17cec995ad4de8d279cd6d49af6.bindPopup(popup_185103e2e6a1a954a0d648bbde1a3a72)
#         ;
#
#
#
#
#             var circle_marker_1147f3e0a8b31ec6df5ceb1db0d04edb = L.circleMarker(
#                 [37.7299809672996, -122.388856204292],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1c652820aab349fd00b584a6e2f57af8);
#
#
#         var popup_e071fb4ba1acb27ad25d468c9bcf70cb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b188a42684ca03370845db7cde6096b2 = $(`&lt;div id=&quot;html_b188a42684ca03370845db7cde6096b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WARRANTS&lt;/div&gt;`)[0];
#             popup_e071fb4ba1acb27ad25d468c9bcf70cb.setContent(html_b188a42684ca03370845db7cde6096b2);
#
#
#         circle_marker_1147f3e0a8b31ec6df5ceb1db0d04edb.bindPopup(popup_e071fb4ba1acb27ad25d468c9bcf70cb)
#         ;
#
#
#
#
#             var circle_marker_080da90bb749a1d357a240f3269b4fb6 = L.circleMarker(
#                 [37.7857883766888, -122.412970537591],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&qu

# %% [markdown]
# ¿No es esto realmente genial? Ahora puedes saber qué categoría de incidente ocurrió en cada marcador.
#
# Si encuentras que el mapa está tan congestionado con todos estos marcadores, hay dos soluciones para este problema. La más simple es eliminar estos marcadores de ubicación y simplemente agregar el texto a los marcadores de círculo de la siguiente manera:

# %%
# creamos el mapa y lo mostramos
sanfran_map = folium.Map(location=[latitude, longitude], zoom_start=12)

# recorremos los 100 delitos y agregamos cada uno al mapa
for lat, lng, label in zip(df_incidents.Y, df_incidents.X, df_incidents.Category):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5, # definimos cuan grande queremos que sean los marcadores circulares
        color='yellow',
        fill=True,
        popup=label,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(sanfran_map)

# mostramos el mapa
sanfran_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4b32d3743e8331b5e3ac9420828bcdb7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4b32d3743e8331b5e3ac9420828bcdb7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_4b32d3743e8331b5e3ac9420828bcdb7 = L.map(
#                 &quot;map_4b32d3743e8331b5e3ac9420828bcdb7&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3057f8f59ec8c9c47d7f02451aea0674 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4b32d3743e8331b5e3ac9420828bcdb7);
#
#
#             var circle_marker_77bacfe3c021e474ec3b61efdda2e634 = L.circleMarker(
#                 [37.775420706711, -122.403404791479],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4b32d3743e8331b5e3ac9420828bcdb7);
#
#
#         var popup_8733e4337710f890dc0dd4c63b3e77e1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6ac03baa0ae8521d43fb7a74b505f1e5 = $(`&lt;div id=&quot;html_6ac03baa0ae8521d43fb7a74b505f1e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#             popup_8733e4337710f890dc0dd4c63b3e77e1.setContent(html_6ac03baa0ae8521d43fb7a74b505f1e5);
#
#
#         circle_marker_77bacfe3c021e474ec3b61efdda2e634.bindPopup(popup_8733e4337710f890dc0dd4c63b3e77e1)
#         ;
#
#
#
#
#             var circle_marker_50aeadc477930c85164c16716ab6e076 = L.circleMarker(
#                 [37.775420706711, -122.403404791479],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4b32d3743e8331b5e3ac9420828bcdb7);
#
#
#         var popup_8337ba94139f9b32dbb1f3e5890eada1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3ee309c2c0004c62f98969474945455e = $(`&lt;div id=&quot;html_3ee309c2c0004c62f98969474945455e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#             popup_8337ba94139f9b32dbb1f3e5890eada1.setContent(html_3ee309c2c0004c62f98969474945455e);
#
#
#         circle_marker_50aeadc477930c85164c16716ab6e076.bindPopup(popup_8337ba94139f9b32dbb1f3e5890eada1)
#         ;
#
#
#
#
#             var circle_marker_2cb29383bac0d65129d6272aa0cffd5c = L.circleMarker(
#                 [37.7299809672996, -122.388856204292],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4b32d3743e8331b5e3ac9420828bcdb7);
#
#
#         var popup_daf8db26ee586a8926e7a9f1c583266e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7a95c637eec0a09fb43927847ad382d1 = $(`&lt;div id=&quot;html_7a95c637eec0a09fb43927847ad382d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WARRANTS&lt;/div&gt;`)[0];
#             popup_daf8db26ee586a8926e7a9f1c583266e.setContent(html_7a95c637eec0a09fb43927847ad382d1);
#
#
#         circle_marker_2cb29383bac0d65129d6272aa0cffd5c.bindPopup(popup_daf8db26ee586a8926e7a9f1c583266e)
#         ;
#
#
#
#
#             var circle_marker_3b03533be0deb939aa7a000b75456ebb = L.circleMarker(
#                 [37.7857883766888, -122.412970537591],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&qu

# %% [markdown]
# La otra solución es agrupar los marcadores en diferentes grupos. Luego, cada grupo se representa por el número de delitos en cada barrio. Estos grupos se pueden considerar como focos de San Francisco que pueden ser analizados por separado.
#
# Para implementar esto, comenzamos instanciando un objeto *MarkerCluster* y agregando todos los puntos de datos en el dataframe a este objeto.

# %%
from folium import plugins

# empecemos de nuevo con una copia limpia del mapa de San Francisco
sanfran_map = folium.Map(location = [latitude, longitude], zoom_start = 12)

# instanciamos un objeto mark cluster para los incidentes en el dataframe
incidents = plugins.MarkerCluster().add_to(sanfran_map)

# recorremos el dataframe y agregamos cada punto de datos al mark cluster
for lat, lng, label, in zip(df_incidents.Y, df_incidents.X, df_incidents.Category):
    folium.Marker(
        location=[lat, lng],
        icon=None,
        popup=label,
    ).add_to(incidents)

# mostramos el mapa
sanfran_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_69842df488f275cea51101396fc6e785 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_69842df488f275cea51101396fc6e785&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_69842df488f275cea51101396fc6e785 = L.map(
#                 &quot;map_69842df488f275cea51101396fc6e785&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7cf0ed62d33a10ab532c2d96d80534aa = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_69842df488f275cea51101396fc6e785);
#
#
#             var marker_cluster_ab29917893ddef6d58c3708e4fce72a9 = L.markerClusterGroup(
#                 {}
#             );
#             map_69842df488f275cea51101396fc6e785.addLayer(marker_cluster_ab29917893ddef6d58c3708e4fce72a9);
#
#
#             var marker_c9a07ab56252669f6cfd4d7faaec188d = L.marker(
#                 [37.775420706711, -122.403404791479],
#                 {}
#             ).addTo(marker_cluster_ab29917893ddef6d58c3708e4fce72a9);
#
#
#         var popup_ca8a0488349c8ea8a448bcdffe71d7de = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_8f919d44711e1cafb015ff8eaca51e5b = $(`&lt;div id=&quot;html_8f919d44711e1cafb015ff8eaca51e5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#             popup_ca8a0488349c8ea8a448bcdffe71d7de.setContent(html_8f919d44711e1cafb015ff8eaca51e5b);
#
#
#         marker_c9a07ab56252669f6cfd4d7faaec188d.bindPopup(popup_ca8a0488349c8ea8a448bcdffe71d7de)
#         ;
#
#
#
#
#             var marker_6031e0afe00f28819d5cd2529389def1 = L.marker(
#                 [37.775420706711, -122.403404791479],
#                 {}
#             ).addTo(marker_cluster_ab29917893ddef6d58c3708e4fce72a9);
#
#
#         var popup_90f41ca1361a48f52aa396ddae9c7c31 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f79816eec54f20e6a3d91951daa6e04c = $(`&lt;div id=&quot;html_f79816eec54f20e6a3d91951daa6e04c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#             popup_90f41ca1361a48f52aa396ddae9c7c31.setContent(html_f79816eec54f20e6a3d91951daa6e04c);
#
#
#         marker_6031e0afe00f28819d5cd2529389def1.bindPopup(popup_90f41ca1361a48f52aa396ddae9c7c31)
#         ;
#
#
#
#
#             var marker_87dfffed395569853378ee673c766b69 = L.marker(
#                 [37.7299809672996, -122.388856204292],
#                 {}
#             ).addTo(marker_cluster_ab29917893ddef6d58c3708e4fce72a9);
#
#
#         var popup_aaaa90aed902e121ea40cbec0d3bff22 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_8fed95ae9a336447323c332feddac30c = $(`&lt;div id=&quot;html_8fed95ae9a336447323c332feddac30c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WARRANTS&lt;/div&gt;`)[0];
#             popup_aaaa90aed902e121ea40cbec0d3bff22.setContent(html_8fed95ae9a336447323c332feddac30c);
#
#
#         marker_87dfffed395569853378ee673c766b69.bindPopup(popup_aaaa90aed902e121ea40cbec0d3bff22)
#         ;
#
#
#
#
#             var marker_ae8df71d8cc7289a186cda2875ec5ef7 = L.marker(
#                 [37.7857883766888, -122.412970537591],
#                 {}
#             ).addTo(marker_cluster_ab29917893ddef6d58c3708e4fce72a9);
#
#
#         var popup_d8ca5aab37ce3739b09c4d35739889b3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3fcbd78e5bea029197e93df0e83312cf = $(`&lt;div id=&quot;html_3fcbd78e5bea029197e93df0e83312cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NON-CRIMINAL&lt;/div&gt;`)[0];
#             popup_d8ca5aab37ce3739b09c4d35739889b3.setContent(html_3fcbd78e5bea029197e93df0e83312cf);
#
#
#         marker_ae8df71d8cc7289a186cda2875ec5ef7.bindPopup(popup_d8ca5aab37ce3739b09c4d35739889b3)
#         ;
#
#
#
#
#             var marker_005d34eecb10065a1f46da9733ead424 = L.marker(
#                 [37.7650501214668, -122.419671780296],
#                 {}
#             ).addTo(marker_cluster_ab29917893ddef6d58c3708e4fce72a9);
#
#
#         var popup_1a26df14443df2596910768ea8762b35 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_08dbb19309446319dcf5d5ce4a25bb28 = $(`&lt;div id=&quot;

# %% [markdown]
# Observa cómo, cuando se aleja por completo, todos los marcadores se agrupan en un grupo, *el global cluster*, de 100 marcadores o incidentes, que es el número total de incidentes en nuestro dataframe. Una vez que comiences a acercar, el *global cluster* comenzará a dividirse en grupos más pequeños. Acercar por completo dará como resultado marcadores individuales.

# %% [markdown]
# # Mapas de Coropletas <a id="8"></a>
#
# Un mapa de `Coropletas` es un mapa temático en el que las áreas están sombreadas o modeladas en proporción a la medida de la variable estadística que se muestra en el mapa, como la densidad de población o el ingreso per cápita. El mapa de coropletas proporciona una manera fácil de visualizar cómo varía una medida en un área geográfica, o muestra el nivel de variabilidad dentro de una región. A continuación se muestra un mapa de `Coropletas` de los EE. UU. que muestra la población por milla cuadrada por estado.
#
# <img src = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/labs/Module%205/images/2000_census_population_density_map_by_state.png" width = 600>

# %% [markdown]
# Ahora, vamos a crear nuestro propio mapa de `Coropletas` del mundo que represente la inmigración de varios países a Canadá.

# %% [markdown]
# Descarga el dataset de inmigración canadiense y guárdalo en un dataframe de *pandas*.

# %%
df_can = pd.read_excel("Canada.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-41-94f1b7eca18e> in <module>
# ----> 1 df_can = pd.read_excel("Canada.xlsx")
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
#     363         should_close = True
# --> 364         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     365     elif engine and engine != io.engine:
#     366         raise ValueError(
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1190             else:
#    1191                 ext = inspect_excel_format(
# -> 1192                     content_or_path=path_or_buffer, storage_options=storage_options
#    1193                 )
#    1194                 if ext is None:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1069
#    1070     with get_handle(
# -> 1071         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1072     ) as handle:
#    1073         stream = handle.handle
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     709         else:
#     710             # Binary mode
# --> 711             handle = open(handle, ioargs.mode)
#     712         handles.append(handle)
#     713
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Canada.xlsx'

# %% [markdown]
# Echemos un vistazo a los primeros cinco elementos de nuestro dataset.

# %%
df_can.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-e4b4d6314b9a> in <module>
# ----> 1 df_can.head()
#
# NameError: name 'df_can' is not defined

# %% [markdown]
# Averigüemos cuántas entradas hay en nuestro dataset.

# %%
# imprimimos las dimensiones del dataframe
print(df_can.shape)

# %% [markdown]
# Limpiamos los datos. Haremos algunas modificaciones al dataset original para que sea más fácil crear nuestras visualizaciones. Consulta los cuadernos *Introducción a Matplotlib y gráficos de líneas* y *Gráficos de área, histogramas y gráficos de barras* para obtener una descripción detallada de este preprocesamiento.

# %%
# limpiamos el dataset eliminando columnas innecesarias (ej. REG) 
df_can.drop(['AREA','REG','DEV','Type','Coverage'], axis=1, inplace=True)

# cambiemos el nombre de las columnas para que tengan sentido
df_can.rename(columns={'OdName':'Country', 'AreaName':'Continent','RegName':'Region'}, inplace=True)

# para ser coherentes, hagamos que todas las etiquetas de las columnas sean de tipo string
df_can.columns = list(map(str, df_can.columns))

# añadimos la columna Total
df_can['Total'] = df_can.sum(axis=1)

# años que usaremos en esta lección - útil para trazar más adelante
years = list(map(str, range(1980, 2014)))
print ('data dimensions:', df_can.shape)

# %% [markdown]
# Echemos un vistazo a los primeros cinco elementos de nuestro nuevo dataframe.

# %%
df_can.head()

# %% [markdown]
# Para crear un mapa de `Coropletas`, necesitamos un archivo GeoJSON que defina las áreas/límites del estado, condado o país que nos interesa. En nuestro caso, dado que estamos creando un mapa del mundo, queremos un GeoJSON que defina los límites de todos los países del mundo. Para facilitar la tarea, te proporcionaremos este archivo, así que adelante, cárgalo.

# %%
import json

with open("world_countries.json", 'r') as f:
  world_geo=json.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-43-95e78deb2e78> in <module>
#       1 import json
#       2
# ----> 3 with open("world_countries.json", 'r') as f:
#       4   world_geo=json.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'world_countries.json'

# %% [markdown]
# Ahora que tenemos el archivo GeoJSON, vamos a crear un mapa del mundo, centrado alrededor de los valores **\[0, 0]** *latitud* y *longitud*, con un nivel de zoom inicial de 2.

# %%
# creamos un mapa del mundo plano
world_map = folium.Map(location=[0, 0], zoom_start=2)

# %% [markdown]
# Y ahora, para crear un mapa de `Coropletas`, usaremos el método *choropleth* con los siguientes parámetros principales:
#
# 1.  `geo_data`, que es el archivo GeoJSON.
# 2.  `data`, que es el dataframe que contiene los datos.
# 3.  `columns`, que representa las columnas en el dataframe que se usarán para crear el mapa de `Coropletas`.
# 4.  `key_on`, que es la clave o variable en el archivo GeoJSON que contiene el nombre de la variable de interés. Para determinar esto, deberás abrir el archivo GeoJSON usando cualquier editor de texto y anotar el nombre de la clave o variable que contiene el nombre de los países, ya que los países son nuestra variable de interés. En este caso, **name** es la clave en el archivo GeoJSON que contiene el nombre de los países. Ten en cuenta que esta clave distingue entre mayúsculas y minúsculas, por lo que debes pasar exactamente como está en el archivo GeoJSON.

# %%
# generamos un mapa de coropletas utilizando la inmigración total de cada país a Canadá desde 1980 hasta 2013
world_map.choropleth(
    geo_data=world_geo,
    data=df_can,
    columns=['Country', 'Total'],
    key_on='feature.properties.name',
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='Immigration to Canada'
)

# mostramos el mapa
world_map

# %% [markdown]
# Según la leyenda de nuestro mapa de "Coropletas", cuanto más oscuro es el color de un país y más cercano al rojo, mayor es el número de inmigrantes de ese país. En consecuencia, la mayor inmigración en el transcurso de 33 años (de 1980 a 2013) provino de China, India y Filipinas, seguidos de Polonia, Pakistán y, curiosamente, EE. UU.

# %% [markdown]
# Observa cómo la leyenda muestra un límite o umbral negativo. ¡Arreglemos eso definiendo nuestros propios umbrales y comenzando con 0 en lugar de -6,918!

# %%
# creamos un array numpy de longitud 6 y tiene un espacio lineal desde la inmigración total mínima hasta la inmigración total máxima
threshold_scale = np.linspace(df_can['Total'].min(),
                              df_can['Total'].max(),
                              6, dtype=int)
threshold_scale = threshold_scale.tolist() # cambiamos el array numpy a una lista
threshold_scale[-1] = threshold_scale[-1] + 1 # asegúrate de que el último valor de la lista sea mayor que la inmigración máxima

# dejamos que Folium determine la escala
world_map = folium.Map(location=[0, 0], zoom_start=2)
world_map.choropleth(
    geo_data=world_geo,
    data=df_can,
    columns=['Country', 'Total'],
    key_on='feature.properties.name',
    threshold_scale=threshold_scale,
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='Immigration to Canada',
    reset=True
)
world_map

# %% [markdown]
# ¡Mucho mejor ahora! Siéntete libre de jugar con los datos y tal vez crear mapas de 'Coropletas' para años individuales, o quizás décadas, y ver cómo se comparan con el período completo desde 1980 hasta 2013.
